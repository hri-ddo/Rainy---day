# %%
# !unzip "/content/drive/MyDrive/mlolympiadbd2024.zip"
# Out:
# Archive:  /content/drive/MyDrive/mlolympiadbd2024.zip
# replace Weather_Data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/Weather_Data.csv")

# %%
df.count()
# Out:
# Date             3271
# Temp9am          3271
# Temp3pm          3271
# MinTemp          3271
# MaxTemp          3271
# Rainfall         3271
# RainToday        3271
# Evaporation      3271
# Sunshine         3271
# WindGustDir      3271
# WindGustSpeed    3271
# WindDir9am       3271
# WindDir3pm       3271
# WindSpeed9am     3271
# WindSpeed3pm     3271
# Humidity9am      3271
# Humidity3pm      3271
# Pressure9am      3271
# Pressure3pm      3271
# Cloud9am         3271
# Cloud3pm         3271
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   Temp9am        3271 non-null   float64
#  2   Temp3pm        3271 non-null   float64
#  3   MinTemp        3271 non-null   float64
#  4   MaxTemp        3271 non-null   float64
#  5   Rainfall       3271 non-null   float64
#  6   RainToday      3271 non-null   object
#  7   Evaporation    3271 non-null   float64
#  8   Sunshine       3271 non-null   float64
#  9   WindGustDir    3271 non-null   object
#  10  WindGustSpeed  3271 non-null   int64
#  11  WindDir9am     3271 non-null   object
#  12  WindDir3pm     3271 non-null   object
#  13  WindSpeed9am   3271 non-null   int64
#  14  WindSpeed3pm   3271 non-null   int64
#  15  Humidity9am    3271 non-null   int64
#  16  Humidity3pm    3271 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Date             0
# Temp9am          0
# Temp3pm          0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# RainToday        0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# dtype: int64

# %%
df.Date.dtype
# Out:
# dtype('O')

# %%
df.Date.head(20)
# Out:
# 0     01-02-13
# 1     02-02-13
# 2     03-02-13
# 3     04-02-13
# 4     05-02-13
# 5     06-02-13
# 6     07-02-13
# 7     08-02-13
# 8     09-02-13
# 9     10-02-13
# 10    11-02-13
# 11    12-02-13
# 12    13-02-13
# 13    14-02-13
# 14    15-02-13
# 15    16-02-13
# 16    17-02-13
# 17    18-02-13
# 18    19-02-13
# 19    20-02-13
# Name: Date, dtype: object

# %%
df_tmp=pd.read_csv("/content/train.csv")

# %%
df_tmp['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)

# %%
df_tmp["Year"] = df_tmp.Date.dt.year
df_tmp["Month"] = df_tmp.Date.dt.month
df_tmp["Day"] = df_tmp.Date.dt.day
df_tmp["DayOfWeek"] = df_tmp.Date.dt.dayofweek
df_tmp["DayOfYear"] = df_tmp.Date.dt.dayofyear

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   datetime64[ns]
#  1   Temp9am        3271 non-null   float64
#  2   Temp3pm        3271 non-null   float64
#  3   MinTemp        3271 non-null   float64
#  4   MaxTemp        3271 non-null   float64
#  5   Rainfall       3271 non-null   float64
#  6   RainToday      3271 non-null   object
#  7   Evaporation    3271 non-null   float64
#  8   Sunshine       3271 non-null   float64
#  9   WindGustDir    3271 non-null   object
#  10  WindGustSpeed  3271 non-null   int64
#  11  WindDir9am     3271 non-null   object
#  12  WindDir3pm     3271 non-null   object
#  13  WindSpeed9am   3271 non-null   int64
#  14  WindSpeed3pm   3271 non-null   int64
#  15  Humidity9am    3271 non-null   int64
#  16  Humidity3pm    3271 non-null   int64
# ...

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# RainToday
# WindGustDir
# WindDir9am
# WindDir3pm

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   datetime64[ns]
#  1   Temp9am        3271 non-null   float64
#  2   Temp3pm        3271 non-null   float64
#  3   MinTemp        3271 non-null   float64
#  4   MaxTemp        3271 non-null   float64
#  5   Rainfall       3271 non-null   float64
#  6   RainToday      3271 non-null   category
#  7   Evaporation    3271 non-null   float64
#  8   Sunshine       3271 non-null   float64
#  9   WindGustDir    3271 non-null   category
#  10  WindGustSpeed  3271 non-null   int64
#  11  WindDir9am     3271 non-null   category
#  12  WindDir3pm     3271 non-null   category
#  13  WindSpeed9am   3271 non-null   int64
#  14  WindSpeed3pm   3271 non-null   int64
#  15  Humidity9am    3271 non-null   int64
#  16  Humidity3pm    3271 non-null   int64
# ...

# %%
# Export current tmp dataframe
df_tmp.to_csv("train_tmp.csv",
              index=False)

# %%
df_tmp.isna().sum()
# Out:
# Date             0
# Temp9am          0
# Temp3pm          0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# RainToday        0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Year             0
# Month            0
# Day              0
# DayOfWeek        0
# DayOfYear        0
# dtype: int64

# %%
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        df_tmp[label] = pd.Categorical(content).codes+1

# %%
df_tmp
# Out:
#       Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall  RainToday  \
# 0        1     20.7     20.9     19.5     22.4      15.6          2
# 1       12     22.4     24.8     19.5     25.6       6.0          2
# 2       39     23.5     23.0     21.6     24.5       6.6          2
# 3       69     21.4     20.9     20.2     22.8      18.8          2
# 4       98     22.5     25.5     19.7     25.7      77.4          2
# ...    ...      ...      ...      ...      ...       ...        ...
# 2611  2585     15.1     20.1     11.6     20.5       0.0          1
# 2612  2586     14.6     18.5     10.6     20.8       0.0          1
# 2613  2587     13.0     20.1      9.0     20.3       0.0          1
# 2614  2588     12.1     18.1      8.3     18.7       0.0          1
# 2615  2589     13.9     18.4      9.6     19.7       0.0          1
#
#       Evaporation  Sunshine  WindGustDir  ...  Pressure9am  Pressure3pm  \
# 0             6.2       0.0           14  ...       1017.6       1017.4
# ...

# %%
X=df_tmp.drop("RainToday",axis=1)
y=df_tmp["RainToday"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
model_fc=RandomForestClassifier()
model_fc.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
model_fc.score(X_test,y_test)
# Out:
# 0.9176829268292683

# %%
model_log=LogisticRegression()
model_log.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_log.score(X_test,y_test)
# Out:
# 0.875

# %%
from xgboost import XGBClassifier
bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
y_train_binary = (y_train == 1).astype(int)
bst.fit(X_train, y_train_binary)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=2, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_test_binary = (y_test == 1).astype(int)
bst.score(X_test,y_test_binary)
# Out:
# 0.8658536585365854

# %% [markdown]
# # Hyper pera meters

# %%
from sklearn.model_selection import RandomizedSearchCV

#RandomForestRegressor hyperparameters
xg_grid={
    "n_estimators": np.arange(2, 100, 10),
    "max_depth": [None, 3, 5, 10],
    "learning_rate":[0.01,0.1,1],
    "objective":['binary:logistic']
}
rf_grid = {"n_estimators": np.arange(10, 100, 10),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2),
           "max_features": [0.5, 1, "sqrt", "auto"]}
# Create a hyperparameter grid for LogisticRegression
log_reg_grid = {"C": np.logspace(-4, 4, 20),
                "solver": ["liblinear"]}

rs_log_reg = RandomizedSearchCV(LogisticRegression(),
                                param_distributions=log_reg_grid,
                                cv=5,
                                n_iter=20,
                                verbose=True)

# Instantiate RandomizedSearchCV model
rs_rf = RandomizedSearchCV(RandomForestClassifier(),
                           param_distributions=rf_grid,
                           cv=5,
                           n_iter=20,
                           verbose=True)
rs_xg=RandomizedSearchCV(XGBClassifier(),
                                param_distributions=xg_grid,
                                cv=5,
                                n_iter=20,
                                verbose=True)

# %% [markdown]
# ## xg boost

# %%
np.random.seed(42)
y_train_binary = (y == 1).astype(int)
rs_xg.fit(X, y_train_binary)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
# ...

# %%
# Out:
# 0.8780487804878049

# %% [markdown]
# # Random forrest

# %%
np.random.seed(42)
rs_rf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
rs_rf.score(X_test,y_test)
# Out:
# 0.9115853658536586

# %%
rs_rf.best_params_
# Out:
# {'n_estimators': 90,
#  'min_samples_split': 12,
#  'min_samples_leaf': 7,
#  'max_features': 'sqrt',
#  'max_depth': 10}

# %% [markdown]
# # Logestic

# %%
rs_log_reg.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=20,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'solver': ['liblinear']},
#                    verbose=True)

# %%
rs_log_reg.score(X_test,y_test)
# Out:
# 0.8902439024390244

# %%
# !unzip "/content/drive/MyDrive/mlolympiadbd2024 (1).zip"
# Out:
# Archive:  /content/drive/MyDrive/mlolympiadbd2024 (1).zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
df_test=pd.read_csv("/content/test.csv")

# %%
df_test
# Out:
#          Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 0    01-04-20     12.7     17.0      9.0     19.7       0.0        No
# 1    02-04-20     11.9     18.6      8.0     18.8       0.0       Yes
# 2    03-04-20     14.4     20.6     11.2     20.8       2.8       Yes
# 3    04-04-20     13.7     18.3     12.5     19.5      20.4        No
# 4    05-04-20     15.2     18.7     11.5     21.7       0.0        No
# ..        ...      ...      ...      ...      ...       ...       ...
# 650  11-01-22     10.5     17.9      8.6     19.6       0.0        No
# 651  12-01-22     11.0     18.7      9.3     19.2       0.0        No
# 652  13-01-22     10.2     17.3      9.4     17.7       0.0        No
# 653  14-01-22     12.4     19.0     10.1     19.3       0.0        No
# 654  15-01-22      9.4     18.8      7.6     19.3       0.0        No
#
#      Evaporation  Sunshine WindGustDir  ...  WindDir3pm WindSpeed9am  \
# ...

# %%
df_train=pd.read_csv("/content/train.csv")
df_train
# Out:
#           Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 0     01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 1     02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 2     03-02-13     23.5     23.0     21.6     24.5       6.6       Yes
# 3     04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 4     05-02-13     22.5     25.5     19.7     25.7      77.4       Yes
# ...        ...      ...      ...      ...      ...       ...       ...
# 2611  27-03-20     15.1     20.1     11.6     20.5       0.0        No
# 2612  28-03-20     14.6     18.5     10.6     20.8       0.0        No
# 2613  29-03-20     13.0     20.1      9.0     20.3       0.0        No
# 2614  30-03-20     12.1     18.1      8.3     18.7       0.0        No
# 2615  31-03-20     13.9     18.4      9.6     19.7       0.0        No
#
#       Evaporation  Sunshine WindGustDir  ...  WindDir3pm WindSpeed9am  \
# ...

# %%
def preprocess_data(df):

    df.drop("RainToday", axis=1, inplace=True)
    df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
    df["Year"] = df.Date.dt.year
    df["Month"] = df.Date.dt.month
    df["Day"] = df.Date.dt.day
    df["DayOfWeek"] = df.Date.dt.dayofweek
    df["DayOfYear"] = df.Date.dt.dayofyear

    for label, content in df.items():
        if not pd.api.types.is_numeric_dtype(content):
            df[label] = pd.Categorical(content).codes+1



    return df

# %%
df_pre=preprocess_data(df_test)

# %%
df_pre
# Out:
#      Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       1     12.7     17.0      9.0     19.7       0.0          3.2
# 1      10     11.9     18.6      8.0     18.8       0.0          4.0
# 2      19     14.4     20.6     11.2     20.8       2.8          5.6
# 3      28     13.7     18.3     12.5     19.5      20.4          4.0
# 4      55     15.2     18.7     11.5     21.7       0.0          2.8
# ..    ...      ...      ...      ...      ...       ...          ...
# 650   654     10.5     17.9      8.6     19.6       0.0          2.0
# 651   655     11.0     18.7      9.3     19.2       0.0          2.0
# 652   642     10.2     17.3      9.4     17.7       0.0          2.4
# 653   643     12.4     19.0     10.1     19.3       0.0          1.4
# 654   644      9.4     18.8      7.6     19.3       0.0          3.4
#
#      Sunshine  WindGustDir  WindGustSpeed  ...  Pressure9am  Pressure3pm  \
# ...

# %%
df_test2=pd.read_csv("/content/test.csv")
df_test2
# Out:
#          Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 0    01-04-20     12.7     17.0      9.0     19.7       0.0        No
# 1    02-04-20     11.9     18.6      8.0     18.8       0.0       Yes
# 2    03-04-20     14.4     20.6     11.2     20.8       2.8       Yes
# 3    04-04-20     13.7     18.3     12.5     19.5      20.4        No
# 4    05-04-20     15.2     18.7     11.5     21.7       0.0        No
# ..        ...      ...      ...      ...      ...       ...       ...
# 650  11-01-22     10.5     17.9      8.6     19.6       0.0        No
# 651  12-01-22     11.0     18.7      9.3     19.2       0.0        No
# 652  13-01-22     10.2     17.3      9.4     17.7       0.0        No
# 653  14-01-22     12.4     19.0     10.1     19.3       0.0        No
# 654  15-01-22      9.4     18.8      7.6     19.3       0.0        No
#
#      Evaporation  Sunshine WindGustDir  ...  WindDir3pm WindSpeed9am  \
# ...

# %%
test_preds = rs_rf.predict(df_pre)

# %%
solve = {}

for index, content in enumerate(test_preds):
    if content == 2:
        solve[index] = "Yes"
    else:
        solve[index] = "No"

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-5948db3a82ea> in <cell line: 1>()
# ----> 1 solve[:20]
#
# TypeError: unhashable type: 'slice'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-55777701136e> in <cell line: 1>()
# ----> 1 pd.to_csv("/content/sample_submission(2).csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
sample_sub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-8704db3e1b23> in <cell line: 1>()
# ----> 1 sample_sub
#
# NameError: name 'sample_sub' is not defined

# %%
df_preds = pd.DataFrame()
df_preds['ID'] = range(1, len(test_preds) + 1)
df_preds["Predicted"] = solve

# %%
df_preds.to_csv("sample_sub(4).csv",index=False)

# %%
df_preds
# Out:
#       ID Predicted
# 0      1        No
# 1      2        No
# 2      3        No
# 3      4        No
# 4      5        No
# ..   ...       ...
# 650  651        No
# 651  652        No
# 652  653        No
# 653  654        No
# 654  655        No
#
# [655 rows x 2 columns]

# %%
pd.read
